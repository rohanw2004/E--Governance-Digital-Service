# %% [markdown]
# # Week 2 — Data Collection and Cleaning
#
# ## Project Title
# Analysis of Digital Governance Adoption using E-Panchayat Data
#
# ## Objective
# To clean, preprocess, and prepare governance datasets for analytical evaluation of digital adoption across Indian states.

# %% [markdown]
# ### 1.IMPORTING LIBRARIES
# importing library to on our required dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2.LOAD DATASET
# loading a dataset o work on the actual course of project.

# %%
df = pd.read_csv('C:\\Users\\lenovo\\OneDrive\\Desktop\\rohan academical inventory\\yuva internship\\E---Governance-Digital-Service\\data\\raw\\e_goverance-dataset.csv')

# %% [markdown]
# ### 3.INITIAL DATA INSPECTION
# Inspecting with te data available in the csv file to reassure which datas are need to be cleand and to be filled
#
# Checking if the file is fit properly

# %%
df.head()
# Out:
#   Si. No.             States Total Number of Village Panchayats & Equivalent  \
# 0       1     Andhra Pradesh                                               Y
# 1       2  Arunachal Pradesh                                               Y
# 2       3              Assam                                               Y
# 3       4              Bihar                                               Y
# 4       5       Chhattisgarh                                               Y
#
#    Gram Panchayat Development Plans Uploaded  Gram Panchayats Ported  \
# 0                                      13371                   13351
# 1                                       2108                    1577
# 2                                       2666                    2119
# 3                                       8135                    8135
# 4                                      11658                   11658
#
#    Total Number of Block Panchayats & Equivalent  \
# ...

# %%
df.tail()
# Out:
#    Si. No.         States Total Number of Village Panchayats & Equivalent  \
# 26      27        Tripura                                               Y
# 27      28    Uttarakhand                                               Y
# 28      29  Uttar Pradesh                                               Y
# 29      30    West Bengal                                               Y
# 30   Total          Total                                           Total
#
#     Gram Panchayat Development Plans Uploaded  Gram Panchayats Ported  \
# 26                                       1219                    1178
# 27                                       7791                    7791
# 28                                      58189                   58189
# 29                                       3341                    3228
# 30                                     270946                  255021
#
#     Total Number of Block Panchayats & Equivalent  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Si. No.                                          31 non-null     object
#  1   States                                           31 non-null     object
#  2   Total Number of Village Panchayats & Equivalent  29 non-null     object
#  3   Gram Panchayat Development Plans Uploaded        31 non-null     int64
#  4   Gram Panchayats Ported                           31 non-null     int64
#  5   Total Number of Block Panchayats & Equivalent    31 non-null     int64
#  6   Block Panchayats Plan uploaded                   31 non-null     int64
#  7   Total Number of ZillaPanchayats& Equivalent      31 non-null     int64
#  8   ZillaPanchayats Plan uploaded                    31 non-null     int64
# ...

# %% [markdown]
# Checking the values available in the top column

# %%
print(df.columns.tolist())
# Out:
# ['Si. No.', 'States', 'Total Number of Village Panchayats & Equivalent', 'Gram Panchayat Development Plans Uploaded', 'Gram Panchayats Ported', 'Total Number of Block Panchayats & Equivalent', 'Block Panchayats Plan uploaded', 'Total Number of ZillaPanchayats& Equivalent', 'ZillaPanchayats Plan uploaded', 'Gram Panchayat on onboard', 'Gram Panchayat With Online Payment', 'Plans Uploaded']

# %%
df.describe()
# Out:
#        Gram Panchayat Development Plans Uploaded  Gram Panchayats Ported  \
# count                                  31.000000               31.000000
# mean                                17480.387097            16452.967742
# std                                 48367.861181            45734.478490
# min                                   185.000000                0.000000
# 25%                                  2387.000000             1386.000000
# 50%                                  6225.000000             4865.000000
# 75%                                 12647.000000            12646.000000
# max                                270946.000000           255021.000000
#
#        Total Number of Block Panchayats & Equivalent  \
# count                                      31.000000
# mean                                    15403.612903
# std                                     43039.639747
# min                                         0.000000
# ...

# %% [markdown]
# ### 4.DATA STANDARDIZATION
# Before Handling missing values we will approximately standardized our data.
# making categorial data consistency

# %%
df["States"] = df["States"].str.strip()

# %%
df["States"] = df["States"].str.title()

# %% [markdown]
# Cleaning the columns and unnecessary space/ insights from the chart as well as restructuring the sentence into a whol word data

# %%
df.columns = df.columns.str.strip()
df.columns = df.columns.str.replace(" ", "_")

# %% [markdown]
# ### 5.DATA CLEANING

# %% [markdown]
# Seperately storing the value total from the dataset column and row which can bfring error if neglect.

# %%
total_row = df[df['States'] == 'Total']

# %%
df = df[df['States'] != 'Total']

# %% [markdown]
# Removing/dropping the unnecessary columns available in the dataset

# %%
df.drop(columns=['Si._No.'], inplace=True)

# %% [markdown]
# Dropping the column beause it cntains the data value "Y' which actually creates confusion to the dataset

# %%
df.drop(
    columns=['Total_Number_of_Village_Panchayats_&_Equivalent'],
    inplace=True
)

# %% [markdown]
# Checking whether the coluns have been removed/dropped correctly or not.

# %%
print(df.columns.tolist())
# Out:
# ['States', 'Gram_Panchayat_Development_Plans_Uploaded', 'Gram_Panchayats_Ported', 'Total_Number_of_Block_Panchayats_&_Equivalent', 'Block_Panchayats_Plan_uploaded', 'Total_Number_of_ZillaPanchayats&_Equivalent', 'ZillaPanchayats_Plan_uploaded', 'Gram_Panchayat_on_onboard', 'Gram_Panchayat_With_Online_Payment', 'Plans_Uploaded']

# %% [markdown]
# ### 6.MISSING VALUE HANDLING
# Checking all the missing data in he chart

# %%
df.isnull().sum()
# Out:
# States                                           0
# Gram_Panchayat_Development_Plans_Uploaded        0
# Gram_Panchayats_Ported                           0
# Total_Number_of_Block_Panchayats_&_Equivalent    0
# Block_Panchayats_Plan_uploaded                   0
# Total_Number_of_ZillaPanchayats&_Equivalent      0
# ZillaPanchayats_Plan_uploaded                    0
# Gram_Panchayat_on_onboard                        0
# Gram_Panchayat_With_Online_Payment               0
# Plans_Uploaded                                   0
# dtype: int64

# %% [markdown]
# ### 7.DATA TYPE CONVERSION
# as I have heard that Government stores the data not just in numbers but also in alphabets, digits, symbols. To check we will perform:

# %%
numeric_columns = [
    'Plans_Uploaded',
    'Gram_Panchayats_Ported'
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.head()
# Out:
#               States  Gram_Panchayat_Development_Plans_Uploaded  \
# 0     Andhra Pradesh                                      13371
# 1  Arunachal Pradesh                                       2108
# 2              Assam                                       2666
# 3              Bihar                                       8135
# 4       Chhattisgarh                                      11658
#
#    Gram_Panchayats_Ported  Total_Number_of_Block_Panchayats_&_Equivalent  \
# 0                   13351                                          13073
# 1                    1577                                           2034
# 2                    2119                                           2201
# 3                    8135                                           8135
# 4                   11658                                          11657
#
#    Block_Panchayats_Plan_uploaded  \
# 0                             660
# 1                               0
# ...

# %% [markdown]
# ### 8.DUPLICATE VALIDATION
# Checking if the duplicates exist in the file to remove them and make it clear sheet for analysis.(For duplicate Vldation)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Cleaning all the duplicate data to make it a clear working and analysis based data file.
#
#  (Performing for safety even i can see there is no duplicte existing)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### 9. FEATURE ENGINEERING
# Here, No we will sum up all the required information from the data which is been used by government.
#
# First, plans uploaded

# %% [markdown]
# Then, Total number of blocks

# %%
df['Total_number(sum)'] = (
    df['Gram_Panchayat_Development_Plans_Uploaded']
    + df['Gram_Panchayats_Ported']
    + df['Plans_Uploaded']
)

# %% [markdown]
# Now, We are Going to rationalize the data divisional information based on project.

# %%
df['Adoption_percentage'] = (
    df['Plans_Uploaded']
    / df['Gram_Panchayats_Ported']
) * 100

# %% [markdown]
# round percentage of the actual data.

# %%
df['Adoption_percentage'] = df['Adoption_percentage'].round(2)

# %%
df.head()
# Out:
#               States  Gram_Panchayat_Development_Plans_Uploaded  \
# 0     Andhra Pradesh                                      13371
# 1  Arunachal Pradesh                                       2108
# 2              Assam                                       2666
# 3              Bihar                                       8135
# 4       Chhattisgarh                                      11658
#
#    Gram_Panchayats_Ported  Total_Number_of_Block_Panchayats_&_Equivalent  \
# 0                   13351                                          13073
# 1                    1577                                           2034
# 2                    2119                                           2201
# 3                    8135                                           8135
# 4                   11658                                          11657
#
#    Block_Panchayats_Plan_uploaded  \
# 0                             660
# 1                               0
# ...

# %% [markdown]
# ### 10. DATA VALIDATION

# %% [markdown]
# this function call is to check the uniqueness of the data.

# %%
df["States"].nunique()
# Out:
# 30

# %%
print(df.shape)
# Out:
# (30, 12)

# %% [markdown]
# Checking possible negative governance values in he government dataset

# %%
(df.select_dtypes(include='number') < 0).sum()
# Out:
# Gram_Panchayat_Development_Plans_Uploaded        0
# Gram_Panchayats_Ported                           0
# Total_Number_of_Block_Panchayats_&_Equivalent    0
# Block_Panchayats_Plan_uploaded                   0
# Total_Number_of_ZillaPanchayats&_Equivalent      0
# ZillaPanchayats_Plan_uploaded                    0
# Gram_Panchayat_on_onboard                        0
# Gram_Panchayat_With_Online_Payment               0
# Plans_Uploaded                                   0
# Total_number(sum)                                0
# Adoption_percentage                              0
# dtype: int64

# %% [markdown]
# checking the impossible adoption

# %%
invalid_adoption = df[df["Adoption_percentage"] > 100]

print(invalid_adoption)
# Out:
#        States  Gram_Panchayat_Development_Plans_Uploaded  \
# 11  Karnataka                                       5965
#
#     Gram_Panchayats_Ported  Total_Number_of_Block_Panchayats_&_Equivalent  \
# 11                    4865                                           5965
#
#     Block_Panchayats_Plan_uploaded  \
# 11                             229
#
#     Total_Number_of_ZillaPanchayats&_Equivalent  \
# 11                                          159
#
#     ZillaPanchayats_Plan_uploaded  Gram_Panchayat_on_onboard  \
# 11                             31                         18
#
#     Gram_Panchayat_With_Online_Payment  Plans_Uploaded  Total_number(sum)  \
# 11                                5965            5899              16729
#
#     Adoption_percentage
# 11               121.25

# %% [markdown]
# verifying the calculated columns

# %%
df[[
    "States",
    "Plans_Uploaded",
    "Total_number(sum)",
    "Adoption_percentage"
]].head()
# Out:
#               States  Plans_Uploaded  Total_number(sum)  Adoption_percentage
# 0     Andhra Pradesh               0              26722                 0.00
# 1  Arunachal Pradesh               0               3685                 0.00
# 2              Assam             855               5640                40.35
# 3              Bihar            7863              24133                96.66
# 4       Chhattisgarh           10836              34152                92.95

# %% [markdown]
# checking the data types

# %%
df.dtypes
# Out:
# States                                            object
# Gram_Panchayat_Development_Plans_Uploaded          int64
# Gram_Panchayats_Ported                             int64
# Total_Number_of_Block_Panchayats_&_Equivalent      int64
# Block_Panchayats_Plan_uploaded                     int64
# Total_Number_of_ZillaPanchayats&_Equivalent        int64
# ZillaPanchayats_Plan_uploaded                      int64
# Gram_Panchayat_on_onboard                          int64
# Gram_Panchayat_With_Online_Payment                 int64
# Plans_Uploaded                                     int64
# Total_number(sum)                                  int64
# Adoption_percentage                              float64
# dtype: object

# %% [markdown]
# So, Describe call is used here to check whether the data formatted is perfectly fit on its block. and to evaluate the data-source

# %%
df.describe()
# Out:
#        Gram_Panchayat_Development_Plans_Uploaded  Gram_Panchayats_Ported  \
# count                                  30.000000               30.000000
# mean                                 9031.533333             8500.700000
# std                                 11442.794802            11652.160966
# min                                   185.000000                0.000000
# 25%                                  2247.500000             1290.500000
# 50%                                  6095.000000             4606.500000
# 75%                                 12308.250000            12306.750000
# max                                 58189.000000            58189.000000
#
#        Total_Number_of_Block_Panchayats_&_Equivalent  \
# count                                      30.000000
# mean                                     7958.533333
# std                                     11778.344491
# min                                         0.000000
# ...

# %% [markdown]
# no divisional errors

# %% [markdown]
# ### 11.EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# Here, we will sort th values according to the states, to keep it in arranged ordered

# %%
df.sort_values(
    by='Adoption_percentage',
    ascending=False
)[['States', 'Adoption_percentage']].head(10)
# Out:
#             States  Adoption_percentage
# 11       Karnataka               121.25
# 10       Jharkhand                99.93
# 26         Tripura                99.92
# 18         Mizoram                99.28
# 20          Odisha                98.68
# 29     West Bengal                98.20
# 28   Uttar Pradesh                98.05
# 3            Bihar                96.66
# 14  Madhya Pradesh                95.95
# 4     Chhattisgarh                92.95

# %% [markdown]
# Here, we are filtering and analyzing data

# %%
df[
    df["Adoption_percentage"] > 80
]
# Out:
#             States  Gram_Panchayat_Development_Plans_Uploaded  \
# 3            Bihar                                       8135
# 4     Chhattisgarh                                      11658
# 6          Gujarat                                      14270
# 10       Jharkhand                                       4351
# 11       Karnataka                                       5965
# 14  Madhya Pradesh                                      22741
# 18         Mizoram                                        834
# 20          Odisha                                       6798
# 26         Tripura                                       1219
# 28   Uttar Pradesh                                      58189
# 29     West Bengal                                       3341
#
#     Gram_Panchayats_Ported  Total_Number_of_Block_Panchayats_&_Equivalent  \
# 3                     8135                                           8135
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                                Gram_Panchayat_Development_Plans_Uploaded  \
# Gram_Panchayat_Development_Plans_Uploaded                                       1.000000
# Gram_Panchayats_Ported                                                          0.989630
# Total_Number_of_Block_Panchayats_&_Equivalent                                   0.969390
# Block_Panchayats_Plan_uploaded                                                  0.711659
# Total_Number_of_ZillaPanchayats&_Equivalent                                     0.600451
# ZillaPanchayats_Plan_uploaded                                                   0.799968
# Gram_Panchayat_on_onboard                                                       0.729998
# Gram_Panchayat_With_Online_Payment                                              0.952446
# Plans_Uploaded                                                                  0.938564
# ...

# %% [markdown]
# A bare visualization to check if everything is proper.

# %%
top_states = df.sort_values(
    by='Adoption_percentage',
    ascending=False
).head(10)

plt.figure(figsize=(10,5))

plt.bar(
    top_states['States'],
    top_states['Adoption_percentage']
)

plt.xticks(rotation=45)

plt.title("Top States by Adoption Percentage")

plt.show()

# %% [markdown]
# correlating the analysis

# %%
plt.figure(figsize=(10,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True
)

plt.show()

# %% [markdown]
# ### 12.PRELIMINARY FINDINGS.

# %% [markdown]
# After cleaning and analyzing the E-Panchayat and e-Gram Swaraj dataset, several important observations were identified regarding digital governance adoption across Indian states.
#
# 1. The adoption percentage of digital governance services differs significantly from state to state. Some states show high participation in uploading Panchayat development plans, while others have lower adoption levels.
#
# 2. States with higher adoption percentages appear to have better implementation of digital governance systems and stronger usage of online Panchayat platforms.
#
# 3. The dataset indicates that digital governance in rural administration is growing, especially through online planning and Panchayat management systems.
#
# 4. Some states still show comparatively lower digital adoption, which may be due to differences in infrastructure, awareness, administrative efficiency, or technology accessibility.
#
# 5. During preprocessing and validation, no duplicate records, negative values, or logically incorrect adoption percentages were found. This suggests that the dataset is reliable for further analysis and visualization.
#
# 6. The calculated adoption percentage helped in comparing governance performance across states and identifying leading and lagging regions in digital governance implementation.
#
# Overall, the dataset provides meaningful insights into the progress of Panchayat-level digital governance in India and forms a strong foundation for further visualization and policy analysis.

# %% [markdown]
# ### 13.SAVE CLEAN DATA
# Now, We will save the Cleaned and sorted data in seperate csv file.

# %%
df.to_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\rohan academical inventory\\yuva internship\\E---Governance-Digital-Service\\data\\processed\\e_panchayat_cleaned.csv", index=False)

# %% [markdown]
# ### NOTE
# Zero values were retained in the dataset because they represented valid governance observations rather than missing data. These values were important for identifying states with lower digital governance participation and adoption levels.
