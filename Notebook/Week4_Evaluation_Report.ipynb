# %% [markdown]
# # Week 4: Evaluation and Reporting
#
# This notebook focuses on reviewing analytical outputs generated during previous stages of the project. The purpose of this notebook is to evaluate processed governance data before preparing final findings, recommendations, and reporting.
#
# ## 1.Import required libraries

# %%
import pandas as pd
import numpy as np

print("Week 4 Evaluation Notebook Started")
# Out:
# Week 4 Evaluation Notebook Started

# %% [markdown]
# ## 2.Dataset Loading
#
# The cleaned and processed dataset generated during previous analytical stages is loaded for evaluation purposes. This dataset serves as the foundation for reviewing governance indicators and validating previous analytical results.

# %%
df = pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\rohan academical inventory\\yuva internship\\E---Governance-Digital-Service\\data\\processed\\visualization_dataset.csv")

print("Dataset Loaded Successfully")

df.head()
# Out:
# Dataset Loaded Successfully
#               States  Gram_Panchayat_Development_Plans_Uploaded  \
# 0     Andhra Pradesh                                      13371
# 1  Arunachal Pradesh                                       2108
# 2              Assam                                       2666
# 3              Bihar                                       8135
# 4       Chhattisgarh                                      11658
#
#    Gram_Panchayats_Ported  Total_Number_of_Block_Panchayats_&_Equivalent  \
# 0                   13351                                          13073
# 1                    1577                                           2034
# 2                    2119                                           2201
# 3                    8135                                           8135
# 4                   11658                                          11657
#
#    Block_Panchayats_Plan_uploaded  \
# 0                             660
# 1                               0
# ...

# %% [markdown]
# ## 3.Dataset Structure Analysis
#
# Understanding dataset structure is important before evaluation. This step helps verify column information, datatypes, and overall dataset organization before proceeding with analytical review.
#
# ### Understanding dataset columns and datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   States                                         30 non-null     object
#  1   Gram_Panchayat_Development_Plans_Uploaded      30 non-null     int64
#  2   Gram_Panchayats_Ported                         30 non-null     int64
#  3   Total_Number_of_Block_Panchayats_&_Equivalent  30 non-null     int64
#  4   Block_Panchayats_Plan_uploaded                 30 non-null     int64
#  5   Total_Number_of_ZillaPanchayats&_Equivalent    30 non-null     int64
#  6   ZillaPanchayats_Plan_uploaded                  30 non-null     int64
#  7   Gram_Panchayat_on_onboard                      30 non-null     int64
#  8   Gram_Panchayat_With_Online_Payment             30 non-null     int64
# ...

# %% [markdown]
# ## 4.Statistical Summary
#
# Generating descriptive statistics helps summarize governance indicators and provides a quick overview of numerical distributions, averages, and variation within the dataset.

# %%
df.describe()
# Out:
#        Gram_Panchayat_Development_Plans_Uploaded  Gram_Panchayats_Ported  \
# count                                  30.000000               30.000000
# mean                                 9031.533333             8500.700000
# std                                 11442.794802            11652.160966
# min                                   185.000000                0.000000
# 25%                                  2247.500000             1290.500000
# 50%                                  6095.000000             4606.500000
# 75%                                 12308.250000            12306.750000
# max                                 58189.000000            58189.000000
#
#        Total_Number_of_Block_Panchayats_&_Equivalent  \
# count                                      30.000000
# mean                                     7958.533333
# std                                     11778.344491
# min                                         0.000000
# ...

# %% [markdown]
# ## 5.Dataset Overview
#
# This step provides a simple overview of dataset dimensions by reviewing the number of observations and variables available for analysis.

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 30
# Number of Columns: 12

# %% [markdown]
# ## 6.Missing Value Evaluation
#
# Evaluating missing values is important for understanding data quality and ensuring analytical reliability before reporting findings.

# %%
print("Missing Values Present In Dataset:")
print(df.isnull().sum())
# Out:
# Missing Values Present In Dataset:
# States                                           0
# Gram_Panchayat_Development_Plans_Uploaded        0
# Gram_Panchayats_Ported                           0
# Total_Number_of_Block_Panchayats_&_Equivalent    0
# Block_Panchayats_Plan_uploaded                   0
# Total_Number_of_ZillaPanchayats&_Equivalent      0
# ZillaPanchayats_Plan_uploaded                    0
# Gram_Panchayat_on_onboard                        0
# Gram_Panchayat_With_Online_Payment               0
# Plans_Uploaded                                   0
# Total_number(sum)                                0
# Adoption_percentage                              1
# dtype: int64

# %% [markdown]
# During calculation of adoption percentage, some observations produced undefined values because the required denominator information was unavailable or zero. Such values were retained as missing rather than artificially modified to maintain analytical integrity.

# %% [markdown]
# ## 7.Analytical Review Summary
#
# This section summarizes the analytical workflow completed during previous project phases and explains how the current evaluation supports reporting and recommendation development.

# %%
print("""

Week 4 focuses on evaluation and reporting.

Previous work included:
• Dataset Understanding
• Data Cleaning and Preprocessing
• Feature Engineering
• Visualization and Analysis

This notebook is used for reviewing analytical outputs before preparing recommendations and final reporting.
""")
# Out:
# Week 4 focuses on evaluation and reporting.
#
# Previous work included:
# • Dataset Understanding
# • Data Cleaning and Preprocessing
# • Feature Engineering
# • Visualization and Analysis
#
# This notebook is used for reviewing analytical outputs before preparing recommendations and final reporting.

# %% [markdown]
# # Completion Cell

# %%
print("Week 4 Evaluation Completed Successfully")
# Out:
# Week 4 Evaluation Completed Successfully
